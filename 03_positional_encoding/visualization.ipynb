# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Positional Encoding Visualization\n",
    "\n",
    "This notebook visualizes the sinusoidal positional encodings as described in the paper."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "import torch\n",
    "import matplotlib.pyplot as plt\n",
    "from positional_encoding import PositionalEncoding\n",
    "\n",
    "# Step 1: Initialize positional encoding\n",
    "d_model = 512  # As in paper\n",
    "pe = PositionalEncoding(d_model, max_len=100)  # Short max_len for viz\n",
    "\n",
    "# Step 2: Get the PE tensor (1, max_len, d_model)\n",
    "pe_tensor = pe.pe.squeeze(0).cpu().numpy()  # Remove batch dim\n",
    "\n",
    "# Step 3: Plot the encodings for a few dimensions\n",
    "plt.figure(figsize=(10, 8))\n",
    "for i in range(0, 8, 2):  # Even indices (sine)\n",
    "    plt.plot(pe_tensor[:, i], label=f'Dim {i} (sine)')\n",
    "    plt.plot(pe_tensor[:, i+1], label=f'Dim {i+1} (cosine)')\n",
    "\n",
    "# Step 4: Add labels and show\n",
    "plt.xlabel('Position')\n",
    "plt.ylabel('Encoding Value')\n",
    "plt.title('Sinusoidal Positional Encodings')\n",
    "plt.legend()\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['# Positional Encoding Visualization\n',
#     '\n',
#     'This notebook visualizes the sinusoidal positional encodings as described in the paper.']},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'metadata': {},
#    'outputs': [],
#    'source': ['import torch\n',
#     'import matplotlib.pyplot as plt\n',
#     'from positional_encoding import PositionalEncoding\n',
#     '\n',
#     '# Step 1: Initialize positional encoding\n',
#     'd_model = 512  # As in paper\n',
#     'pe = PositionalEncoding(d_model, max_len=100)  # Short max_len for viz\n',
#     '\n',
#     '# Step 2: Get the PE tensor (1, max_len, d_model)\n',
#     'pe_tensor = pe.pe.squeeze(0).cpu().numpy()  # Remove batch dim\n',
#     '\n',
#     '# Step 3: Plot the encodings for a few dimensions\n',
#     'plt.figure(figsize=(10, 8))\n',
#     'for i in range(0, 8, 2):  # Even indices (sine)\n',
# ...
